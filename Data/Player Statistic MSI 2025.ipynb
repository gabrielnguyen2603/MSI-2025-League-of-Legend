# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# URL of the MSI 2025 Player Statistics page
url = "https://lol.fandom.com/wiki/2025_Mid-Season_Invitational/Player_Statistics?oldid=4214223"

# Send a request to the webpage
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find all tables with player statistics
tables = soup.find_all('table', class_='wikitable')

# Dictionary to store all dataframes
all_stats = {}

# Process each table
for table in tables:
    # Try to find the table header/caption
    caption = table.find('caption')
    if caption:
        table_name = caption.get_text().strip()
    else:
        # If no caption, try to determine table type from first header
        header = table.find('th')
        if header:
            table_name = f"Table_{header.get_text().strip()}"
        else:
            table_name = f"Table_{tables.index(table)}"
    
    # Parse the table into a dataframe
    df = pd.read_html(str(table))[0]
    
    # Clean column names (remove multi-level if present)
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = [' '.join(col).strip() for col in df.columns.values]
    
    # Extract team names from the first row and champion names from the last column
    if not df.empty:
        # Convert first row to string type (team names)
        if len(df) > 0:
            for col in df.columns:
                if pd.notna(df.iloc[0, df.columns.get_loc(col)]):
                    df.iloc[0, df.columns.get_loc(col)] = str(df.iloc[0, df.columns.get_loc(col)])
        
        # Convert last column to string type (champion names)
        last_col = df.columns[-1]
        df[last_col] = df[last_col].astype(str)
    
    # Store in dictionary
    all_stats[table_name] = df

# Display the first table to check what we got
if all_stats:
    print(f"Found {len(all_stats)} tables")
    first_table_name = list(all_stats.keys())[0]
    print(f"Preview of {first_table_name}:")
    display(all_stats[first_table_name].head())
else:
    print("No tables found")
if all_stats:
    print(f"Found {len(all_stats)} tables")
    first_table_name = list(all_stats.keys())[0]
    print(f"Preview of {first_table_name}:")
    display(all_stats[first_table_name].head())
else:
    print("No tables found")
# Out:
# Found 2 tables
# Preview of Table_Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query:
# C:\Users\nguye\AppData\Local\Temp\ipykernel_20928\2019574670.py:33: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\nguye\AppData\Local\Temp\ipykernel_20928\2019574670.py:33: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport  \
# 0               Restrict By Role (Query Permalinks):
# 1                                                NaN
# 2                                                 ⁠⁠
# 3                                                 ⁠⁠
# 4                                                 ⁠⁠
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.1  \
# 0                                                Top
# 1                                                NaN
# 2                                            Flandre
# 3                                               Hope
# 4                                               Kael
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.2  \
# 0                                             Jungle
# 1                                                  G
# 2                                                 21
# 3                                                 21
# 4                                                 21
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.3  \
# 0                                                Mid
# 1                                                  W
# 2                                                 13
# 3                                                 13
# 4                                                 13
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.4  \
# 0                                                Bot
# 1                                                  L
# 2                                                  8
# 3                                                  8
# 4                                                  8
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.5  \
# 0                                            Support
# 1                                                 WR
# 2                                              61.9%
# 3                                              61.9%
# 4                                              61.9%
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.6  \
# 0                                                NaN
# 1                                                  K
# 2                                               3.14
# 3                                               4.81
# 4                                               0.43
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.7  \
# 0                                                NaN
# 1                                                  D
# 2                                               2.57
# 3                                               2.52
# 4                                               3.24
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.8  \
# 0                                                NaN
# 1                                                  A
# 2                                               6.19
# 3                                               6.24
# 4                                              11.52
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.9  \
# 0                                                NaN
# 1                                                KDA
# 2                                               3.63
# 3                                               4.38
# 4                                               3.69
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.11  \
# 0                                                NaN
# 1                                               CS/M
# 2                                               7.91
# 3                                               9.43
# 4                                               1.14
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.12  \
# 0                                                NaN
# 1                                                  G
# 2                                               12.6
# 3                                               14.4
# 4                                                  8
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.13  \
# 0                                                NaN
# 1                                                G/M
# 2                                                392
# 3                                                448
# 4                                                250
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.14  \
# 0                                                NaN
# 1                                                DMG
# 2                                              19.2k
# 3                                              24.5k
# 4                                               6.7k
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.15  \
# 0                                                NaN
# 1                                              DMG/M
# 2                                              595.2
# 3                                              762.4
# 4                                              209.1
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.16  \
# 0                                                NaN
# 1                                               KPAR
# 2                                              59.9%
# 3                                              70.9%
# 4                                              76.8%
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.17  \
# 0                                                NaN
# 1                                                 KS
# 2                                              20.2%
# 3                                              30.9%
# 4                                               2.8%
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.18  \
# 0                                                NaN
# 1                                                 GS
# 2                                              20.9%
# 3                                              23.8%
# 4                                              13.3%
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.19  \
# 0                                                NaN
# 1                                                 CP
# 2                                                 11
# 3                                                 12
# 4                                                 11
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.20
# 0                                                nan
# 1                                             Champs
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
# [5 rows x 21 columns]
# Found 2 tables
# Preview of Table_Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query:
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport  \
# 0               Restrict By Role (Query Permalinks):
# 1                                                NaN
# 2                                                 ⁠⁠
# 3                                                 ⁠⁠
# 4                                                 ⁠⁠
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.1  \
# 0                                                Top
# 1                                                NaN
# 2                                            Flandre
# 3                                               Hope
# 4                                               Kael
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.2  \
# 0                                             Jungle
# 1                                                  G
# 2                                                 21
# 3                                                 21
# 4                                                 21
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.3  \
# 0                                                Mid
# 1                                                  W
# 2                                                 13
# 3                                                 13
# 4                                                 13
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.4  \
# 0                                                Bot
# 1                                                  L
# 2                                                  8
# 3                                                  8
# 4                                                  8
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.5  \
# 0                                            Support
# 1                                                 WR
# 2                                              61.9%
# 3                                              61.9%
# 4                                              61.9%
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.6  \
# 0                                                NaN
# 1                                                  K
# 2                                               3.14
# 3                                               4.81
# 4                                               0.43
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.7  \
# 0                                                NaN
# 1                                                  D
# 2                                               2.57
# 3                                               2.52
# 4                                               3.24
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.8  \
# 0                                                NaN
# 1                                                  A
# 2                                               6.19
# 3                                               6.24
# 4                                              11.52
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.9  \
# 0                                                NaN
# 1                                                KDA
# 2                                               3.63
# 3                                               4.38
# 4                                               3.69
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.11  \
# 0                                                NaN
# 1                                               CS/M
# 2                                               7.91
# 3                                               9.43
# 4                                               1.14
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.12  \
# 0                                                NaN
# 1                                                  G
# 2                                               12.6
# 3                                               14.4
# 4                                                  8
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.13  \
# 0                                                NaN
# 1                                                G/M
# 2                                                392
# 3                                                448
# 4                                                250
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.14  \
# 0                                                NaN
# 1                                                DMG
# 2                                              19.2k
# 3                                              24.5k
# 4                                               6.7k
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.15  \
# 0                                                NaN
# 1                                              DMG/M
# 2                                              595.2
# 3                                              762.4
# 4                                              209.1
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.16  \
# 0                                                NaN
# 1                                               KPAR
# 2                                              59.9%
# 3                                              70.9%
# 4                                              76.8%
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.17  \
# 0                                                NaN
# 1                                                 KS
# 2                                              20.2%
# 3                                              30.9%
# 4                                               2.8%
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.18  \
# 0                                                NaN
# 1                                                 GS
# 2                                              20.9%
# 3                                              23.8%
# 4                                              13.3%
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.19  \
# 0                                                NaN
# 1                                                 CP
# 2                                                 11
# 3                                                 12
# 4                                                 11
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.20
# 0                                                nan
# 1                                             Champs
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
# [5 rows x 21 columns]

# %%
# Drop the first row from all tables in all_stats
for table_name, df in all_stats.items():
    if not df.empty and len(df) > 1:
        # Drop the first row (index 0)
        all_stats[table_name] = df.iloc[1:].reset_index(drop=True)
        print(f"Dropped first row from {table_name}")

# Display the first table after dropping the first row
if all_stats:
    first_table_name = list(all_stats.keys())[0]
    print(f"\nPreview of {first_table_name} after dropping first row:")
    display(all_stats[first_table_name].head())
# Out:
# Dropped first row from Table_Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query
#
# Preview of Table_Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query after dropping first row:
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport  \
# 0                                                NaN
# 1                                                 ⁠⁠
# 2                                                 ⁠⁠
# 3                                                 ⁠⁠
# 4                                                 ⁠⁠
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.1  \
# 0                                                NaN
# 1                                            Flandre
# 2                                               Hope
# 3                                               Kael
# 4                                             Shanks
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.2  \
# 0                                                  G
# 1                                                 21
# 2                                                 21
# 3                                                 21
# 4                                                 21
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.3  \
# 0                                                  W
# 1                                                 13
# 2                                                 13
# 3                                                 13
# 4                                                 13
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.4  \
# 0                                                  L
# 1                                                  8
# 2                                                  8
# 3                                                  8
# 4                                                  8
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.5  \
# 0                                                 WR
# 1                                              61.9%
# 2                                              61.9%
# 3                                              61.9%
# 4                                              61.9%
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.6  \
# 0                                                  K
# 1                                               3.14
# 2                                               4.81
# 3                                               0.43
# 4                                                  4
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.7  \
# 0                                                  D
# 1                                               2.57
# 2                                               2.52
# 3                                               3.24
# 4                                               2.86
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.8  \
# 0                                                  A
# 1                                               6.19
# 2                                               6.24
# 3                                              11.52
# 4                                               6.71
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.9  \
# 0                                                KDA
# 1                                               3.63
# 2                                               4.38
# 3                                               3.69
# 4                                               3.75
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.11  \
# 0                                               CS/M
# 1                                               7.91
# 2                                               9.43
# 3                                               1.14
# 4                                               8.37
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.12  \
# 0                                                  G
# 1                                               12.6
# 2                                               14.4
# 3                                                  8
# 4                                               13.2
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.13  \
# 0                                                G/M
# 1                                                392
# 2                                                448
# 3                                                250
# 4                                                410
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.14  \
# 0                                                DMG
# 1                                              19.2k
# 2                                              24.5k
# 3                                               6.7k
# 4                                              21.9k
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.15  \
# 0                                              DMG/M
# 1                                              595.2
# 2                                              762.4
# 3                                              209.1
# 4                                                681
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.16  \
# 0                                               KPAR
# 1                                              59.9%
# 2                                              70.9%
# 3                                              76.8%
# 4                                              68.8%
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.17  \
# 0                                                 KS
# 1                                              20.2%
# 2                                              30.9%
# 3                                               2.8%
# 4                                              25.7%
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.18  \
# 0                                                 GS
# 1                                              20.9%
# 2                                              23.8%
# 3                                              13.3%
# 4                                              21.8%
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.19  \
# 0                                                 CP
# 1                                                 11
# 2                                                 12
# 3                                                 11
# 4                                                 12
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.20
# 0                                             Champs
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
# [5 rows x 21 columns]

# %%
# Set the first row as the header for all tables in all_stats
for table_name, df in all_stats.items():
    if not df.empty and len(df) > 0:
        # Use the first row as column headers
        new_headers = df.iloc[0].values
        df = df.iloc[1:].reset_index(drop=True)
        
        # Replace NaN values in headers with original column names
        for i, header in enumerate(new_headers):
            if pd.isna(header) or header == 'nan':
                new_headers[i] = df.columns[i]
        
        # Set the new headers
        df.columns = new_headers
        
        # Update the dataframe in the dictionary
        all_stats[table_name] = df
        print(f"Set first row as header for {table_name}")

# Display the first table after setting the first row as header
if all_stats:
    first_table_name = list(all_stats.keys())[0]
    print(f"\nPreview of {first_table_name} after setting first row as header:")
    display(all_stats[first_table_name].head())
# Out:
# Set first row as header for Table_Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query
# Set first row as header for Table_Restrict By Role (Query Permalinks):
#
# Preview of Table_Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query after setting first row as header:
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport  \
# 0                                                 ⁠⁠
# 1                                                 ⁠⁠
# 2                                                 ⁠⁠
# 3                                                 ⁠⁠
# 4                                                 ⁠⁠
#
#   Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query Player Statistics - 80 Total Games Played, 52 Players Restrict By Role (Query Permalinks):TopJungleMidBotSupport.1  \
# 0                                            Flandre
# 1                                               Hope
# 2                                               Kael
# 3                                             Shanks
# 4                                             Tarzan
#
#     G   W  L     WR     K     D      A   KDA  ...  CS/M     G  G/M    DMG  \
# 0  21  13  8  61.9%  3.14  2.57   6.19  3.63  ...  7.91  12.6  392  19.2k
# 1  21  13  8  61.9%  4.81  2.52   6.24  4.38  ...  9.43  14.4  448  24.5k
# 2  21  13  8  61.9%  0.43  3.24  11.52  3.69  ...  1.14     8  250   6.7k
# 3  21  13  8  61.9%     4  2.86   6.71  3.75  ...  8.37  13.2  410  21.9k
# 4  21  13  8  61.9%  3.19  2.43   8.24  4.71  ...  6.94  12.2  378  15.2k
#
#    DMG/M   KPAR     KS     GS  CP Champs
# 0  595.2  59.9%  20.2%  20.9%  11    nan
# 1  762.4  70.9%  30.9%  23.8%  12    nan
# 2  209.1  76.8%   2.8%  13.3%  11    nan
# 3    681  68.8%  25.7%  21.8%  12    nan
# 4  471.1  73.4%  20.5%  20.1%  11    nan
#
# [5 rows x 21 columns]

# %%
# Set the first column name to "Team" and second column name to "Player Name" for all tables in all_stats
for table_name, df in all_stats.items():
    if not df.empty and len(df.columns) > 1:
        # Get current column names
        current_columns = df.columns.tolist()
        
        # Replace the first column name with "Team" and second column name with "Player Name"
        current_columns[0] = "Team"
        current_columns[1] = "Player Name"
        
        # Set the new column names
        df.columns = current_columns
        
        # Update the dataframe in the dictionary
        all_stats[table_name] = df
        print(f"Set first column name to 'Team' and second column name to 'Player Name' for {table_name}")

# Display the first table after renaming the columns
if all_stats:
    first_table_name = list(all_stats.keys())[0]
    print(f"\nPreview of {first_table_name} after renaming columns:")
    display(all_stats[first_table_name].head())
# Out:
# Set first column name to 'Team' and second column name to 'Player Name' for Table_Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query
#
# Preview of Table_Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query after renaming columns:
#   Team Player Name   G   W  L     WR     K     D      A   KDA  ...  CS/M  \
# 0   ⁠⁠     Flandre  21  13  8  61.9%  3.14  2.57   6.19  3.63  ...  7.91
# 1   ⁠⁠        Hope  21  13  8  61.9%  4.81  2.52   6.24  4.38  ...  9.43
# 2   ⁠⁠        Kael  21  13  8  61.9%  0.43  3.24  11.52  3.69  ...  1.14
# 3   ⁠⁠      Shanks  21  13  8  61.9%     4  2.86   6.71  3.75  ...  8.37
# 4   ⁠⁠      Tarzan  21  13  8  61.9%  3.19  2.43   8.24  4.71  ...  6.94
#
#       G  G/M    DMG  DMG/M   KPAR     KS     GS  CP Champs
# 0  12.6  392  19.2k  595.2  59.9%  20.2%  20.9%  11    nan
# 1  14.4  448  24.5k  762.4  70.9%  30.9%  23.8%  12    nan
# 2     8  250   6.7k  209.1  76.8%   2.8%  13.3%  11    nan
# 3  13.2  410  21.9k    681  68.8%  25.7%  21.8%  12    nan
# 4  12.2  378  15.2k  471.1  73.4%  20.5%  20.1%  11    nan
#
# [5 rows x 21 columns]

# %%
# Drop the first and last columns from all tables in all_stats
for table_name, df in all_stats.items():
    if not df.empty and len(df.columns) > 2:  # Ensure there are at least 3 columns
        # Drop the first and last columns
        df = df.iloc[:, 1:-1]
        
        # Update the dataframe in the dictionary
        all_stats[table_name] = df
        print(f"Dropped first and last columns for {table_name}")

# Display the first table after dropping columns
if all_stats:
    first_table_name = list(all_stats.keys())[0]
    print(f"\nPreview of {first_table_name} after dropping first and last columns:")
    display(all_stats[first_table_name].head())
# Out:
# Dropped first and last columns for Table_Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query
#
# Preview of Table_Tournament: 2025 Mid-Season Invitational - Showing Values Per Game - Open As Query after dropping first and last columns:
#   Player Name   G   W  L     WR     K     D      A   KDA      CS  CS/M     G  \
# 0     Flandre  21  13  8  61.9%  3.14  2.57   6.19  3.63  254.43  7.91  12.6
# 1        Hope  21  13  8  61.9%  4.81  2.52   6.24  4.38  303.43  9.43  14.4
# 2        Kael  21  13  8  61.9%  0.43  3.24  11.52  3.69   36.76  1.14     8
# 3      Shanks  21  13  8  61.9%     4  2.86   6.71  3.75  269.43  8.37  13.2
# 4      Tarzan  21  13  8  61.9%  3.19  2.43   8.24  4.71  223.19  6.94  12.2
#
#    G/M    DMG  DMG/M   KPAR     KS     GS  CP
# 0  392  19.2k  595.2  59.9%  20.2%  20.9%  11
# 1  448  24.5k  762.4  70.9%  30.9%  23.8%  12
# 2  250   6.7k  209.1  76.8%   2.8%  13.3%  11
# 3  410  21.9k    681  68.8%  25.7%  21.8%  12
# 4  378  15.2k  471.1  73.4%  20.5%  20.1%  11
